# %% [markdown]
# # Smeaton 300

# %%
from events import (
    load_raw_data, filter_signature_events, prepare, save_files, count_wards
)

# %% [markdown]
# Set output directory

# %%
OUT_DIR = '../../../../docs/metrics/events/smeaton-300/_data/events'

# %% [markdown]
# Read in event data and filter by **Smeaton 300** projects.
#
# The criteria are:
#
# * project type is 'Produce (Signature)' (in the load_event_data function)
#
# It's then filtered by project_name is '10 - Melt'

# %%
project_names = [
  '09 - Smeaton300: Moon Palace East Leeds Observatory',
  '09 - Smeaton300: Learning programme',
  '09 - Smeaton300: Talks and Discussions'
]
data = (
  load_raw_data()
    # .pipe(filter_signature_events)
)
data = data.loc[data.project_name.isin(project_names)]
data
# Out:
#       actual_audience_size_number_of_participants_in_person  \
# 243                                                 NaN
# 377                                                 NaN
# 649                                                 NaN
# 805                                                20.0
# 806                                                15.0
# ...                                                 ...
# 1376                                                NaN
# 1380                                                NaN
# 1381                                               60.0
# 1383                                              109.0
# 1384                                                NaN
#
#       actual_audience_size_number_of_participants_online  airtable_id  \
# 243                                                 NaN           223
# 377                                                 NaN           222
# 649                                                 NaN          1425
# 805                                                 NaN          2043
# 806                                                 NaN          2042
# ...                                                 ...           ...
# 1376                                                NaN          1375
# 1380                                                NaN          1377
# 1381                                                NaN          2121
# 1383                                                NaN          1380
# 1384                                                NaN          1383
#
#         end_date                                         event_name  \
# 243   2023-05-29           Delivery of Skills Development programme
# 377   2023-07-29         Delivery of Community Engagement programme
# 649   2023-05-23          CREST Award Teacher Consultation Sessions
# 805          NaN             Smeaton CREST Awards - SuperStar Level
# 806          NaN             Smeaton CREST Awards - SuperStar Level
# ...          ...                                                ...
# 1376  2023-11-07                        MOON PALACE: School's Day 2
# 1380  2023-11-08                       MOON PALACE: School's Day 3
# 1381  2023-11-08  STEAM Projects Industry Sharing Day St Peter's...
# 1383  2023-11-09                        MOON PALACE: School's Day 4
# 1384  2023-11-10                    MOON PALACE: School's Day 8 TBC
#
#                                   event_type  \
# 243      ['CLE - Skills and Talent session']
# 377   ['CLE - Community Engagement session']
# 649      ['CLE - Creative Learning session']
# 805      ['CLE - Creative Learning session']
# 806      ['CLE - Creative Learning session']
# ...                                      ...
# 1376     ['CLE - Creative Learning session']
# 1380     ['CLE - Creative Learning session']
# 1381     ['CLE - Creative Learning session']
# 1383     ['CLE - Creative Learning session']
# 1384     ['CLE - Creative Learning session']
#
#                                 event_unique_identifier  \
# 243   09 - Smeaton300: Moon Palace East Leeds Observ...
# 377   09 - Smeaton300: Moon Palace East Leeds Observ...
# 649   09 - Smeaton300: Learning programme: CREST Awa...
# 805   09 - Smeaton300: Learning programme: Smeaton C...
# 806   09 - Smeaton300: Learning programme: Smeaton C...
# ...                                                 ...
# 1376  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1380  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1381  09 - Smeaton300: Learning programme: STEAM Pro...
# 1383  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1384  09 - Smeaton300: Moon Palace East Leeds Observ...
#
#       number_of_booked_participants postcode_(from_venue)  \
# 243                             NaN                   NaN
# 377                             NaN                   NaN
# 649                             NaN          ['LS10 1NE']
# 805                             NaN                   NaN
# 806                             NaN                   NaN
# ...                             ...                   ...
# 1376                            NaN                   NaN
# 1380                            NaN                   NaN
# 1381                            NaN           ['LS9 7SG']
# 1383                            NaN         [' LS10 4AW']
# 1384                            NaN                   NaN
#
#                                            project_name         project_type  \
# 243   09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 377   09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 649                 09 - Smeaton300: Learning programme  Produce (Signature)
# 805                 09 - Smeaton300: Learning programme                  CLE
# 806                 09 - Smeaton300: Learning programme                  CLE
# ...                                                 ...                  ...
# 1376  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1380  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1381                09 - Smeaton300: Learning programme  Produce (Signature)
# 1383  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1384  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
#
#                                               season start_date  \
# 243   ['Season 1 - Awakening', 'Season 2 - Playing'] 2023-02-06
# 377                           ['Season 2 - Playing'] 2023-03-01
# 649                           ['Season 2 - Playing'] 2023-05-02
# 805                          ['Season 3 - Dreaming'] 2023-06-06
# 806                          ['Season 3 - Dreaming'] 2023-06-06
# ...                                              ...        ...
# 1376                         ['Season 3 - Dreaming'] 2023-11-07
# 1380                         ['Season 3 - Dreaming'] 2023-11-08
# 1381                         ['Season 3 - Dreaming'] 2023-11-08
# 1383                         ['Season 3 - Dreaming'] 2023-11-09
# 1384                         ['Season 3 - Dreaming'] 2023-11-10
#
#      ticket_tailor_id                  ward_(from_venue)
# 243               NaN                                NaN
# 377               NaN                                NaN
# 649               NaN          ['Hunslet and Riverside']
# 805               NaN                                NaN
# 806               NaN                                NaN
# ...               ...                                ...
# 1376              NaN                                NaN
# 1380              NaN                                NaN
# 1381              NaN  ['Burmantofts and Richmond Hill']
# 1383              NaN         ['Ardsley and Robin Hood']
# 1384              NaN                                NaN
#
# [66 rows x 15 columns]

# %% [markdown]
# Run the processing and save the files

# %%
data = data.pipe(prepare).pipe(save_files, OUT_DIR)
