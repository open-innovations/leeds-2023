# %% [markdown]
# # Smeaton 300

# %%
from events import (
    load_raw_data, filter_signature_events, prepare, save_files, count_wards
)

# %% [markdown]
# Set output directory

# %%
OUT_DIR = '../../../../docs/metrics/events/smeaton-300/_data/events'

# %% [markdown]
# Read in event data and filter by **Smeaton 300** projects.
#
# The criteria are:
#
# * project type is 'Produce (Signature)' (in the load_event_data function)
#
# It's then filtered by project_name is '10 - Melt'

# %%
project_names = [
  '09 - Smeaton300: Moon Palace East Leeds Observatory',
  '09 - Smeaton300: Learning programme',
  '09 - Smeaton300: Talks and Discussions'
]
data = (
  load_raw_data()
    # .pipe(filter_signature_events)
)
data = data.loc[data.project_name.isin(project_names)]
data
# Out:
#       actual_audience_size_number_of_participants_in_person  \
# 243                                                 NaN
# 377                                                 NaN
# 646                                                 NaN
# 802                                                20.0
# 803                                                15.0
# ...                                                 ...
# 1403                                                NaN
# 1412                                                NaN
# 1413                                                NaN
# 1418                                              178.0
# 1419                                               47.0
#
#       actual_audience_size_number_of_participants_online  airtable_id  \
# 243                                                 NaN           223
# 377                                                 NaN           222
# 646                                                 NaN          1425
# 802                                                 NaN          2043
# 803                                                 NaN          2042
# ...                                                 ...           ...
# 1403                                                NaN          1377
# 1412                                                NaN          2251
# 1413                                                NaN          1380
# 1418                                                NaN          2252
# 1419                                                NaN          1383
#
#         end_date                                         event_name  \
# 243   2023-05-29           Delivery of Skills Development programme
# 377   2023-07-29         Delivery of Community Engagement programme
# 646   2023-05-23          CREST Award Teacher Consultation Sessions
# 802          NaN             Smeaton CREST Awards - SuperStar Level
# 803          NaN             Smeaton CREST Awards - SuperStar Level
# ...          ...                                                ...
# 1403  2023-11-14  MOON PALACE Schools Pupil sessions West Oaks S...
# 1412  2023-11-15  MOON PALACE Schools Family Session St Patrick'...
# 1413  2023-11-15  MOON PALACE Schools Pupil Session at St Patric...
# 1418  2023-11-16  MOON PALACE: Schools Family Sessions at Elemen...
# 1419  2023-11-16  MOON PALACE: Schools Pupil Sessions at Element...
#
#                                   event_type  \
# 243      ['CLE - Skills and Talent session']
# 377   ['CLE - Community Engagement session']
# 646      ['CLE - Creative Learning session']
# 802      ['CLE - Creative Learning session']
# 803      ['CLE - Creative Learning session']
# ...                                      ...
# 1403     ['CLE - Creative Learning session']
# 1412     ['CLE - Creative Learning session']
# 1413     ['CLE - Creative Learning session']
# 1418     ['CLE - Creative Learning session']
# 1419     ['CLE - Creative Learning session']
#
#                                 event_unique_identifier  \
# 243   09 - Smeaton300: Moon Palace East Leeds Observ...
# 377   09 - Smeaton300: Moon Palace East Leeds Observ...
# 646   09 - Smeaton300: Learning programme: CREST Awa...
# 802   09 - Smeaton300: Learning programme: Smeaton C...
# 803   09 - Smeaton300: Learning programme: Smeaton C...
# ...                                                 ...
# 1403  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1412  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1413  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1418  09 - Smeaton300: Moon Palace East Leeds Observ...
# 1419  09 - Smeaton300: Moon Palace East Leeds Observ...
#
#       number_of_booked_participants postcode_(from_venue)  \
# 243                             NaN                   NaN
# 377                             NaN                   NaN
# 646                             NaN          ['LS10 1NE']
# 802                             NaN                   NaN
# 803                             NaN                   NaN
# ...                             ...                   ...
# 1403                            NaN          ['LS23 6DX']
# 1412                            NaN           ['LS9 7QL']
# 1413                            NaN           ['LS9 7QL']
# 1418                            NaN          ['LS10 4WR']
# 1419                            NaN          ['LS10 4WR']
#
#                                            project_name         project_type  \
# 243   09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 377   09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 646                 09 - Smeaton300: Learning programme  Produce (Signature)
# 802                 09 - Smeaton300: Learning programme                  CLE
# 803                 09 - Smeaton300: Learning programme                  CLE
# ...                                                 ...                  ...
# 1403  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1412  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1413  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1418  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
# 1419  09 - Smeaton300: Moon Palace East Leeds Observ...  Produce (Signature)
#
#                                               season start_date  \
# 243   ['Season 1 - Awakening', 'Season 2 - Playing'] 2023-02-06
# 377                           ['Season 2 - Playing'] 2023-03-01
# 646                           ['Season 2 - Playing'] 2023-05-02
# 802                          ['Season 3 - Dreaming'] 2023-06-06
# 803                          ['Season 3 - Dreaming'] 2023-06-06
# ...                                              ...        ...
# 1403                         ['Season 3 - Dreaming'] 2023-11-14
# 1412                         ['Season 3 - Dreaming'] 2023-11-15
# 1413                         ['Season 3 - Dreaming'] 2023-11-15
# 1418                         ['Season 3 - Dreaming'] 2023-11-16
# 1419                         ['Season 3 - Dreaming'] 2023-11-16
#
#      ticket_tailor_id                  ward_(from_venue)
# 243               NaN                                NaN
# 377               NaN                                NaN
# 646               NaN          ['Hunslet and Riverside']
# 802               NaN                                NaN
# 803               NaN                                NaN
# ...               ...                                ...
# 1403              NaN                       ['Wetherby']
# 1412              NaN  ['Burmantofts and Richmond Hill']
# 1413              NaN  ['Burmantofts and Richmond Hill']
# 1418              NaN                 ['Middleton Park']
# 1419              NaN                 ['Middleton Park']
#
# [69 rows x 15 columns]

# %% [markdown]
# Run the processing and save the files

# %%
data = data.pipe(prepare).pipe(save_files, OUT_DIR)
