# %% [markdown]
# # Making a Stand

# %%
import os
from events import (
    load_raw_data, filter_by_project, prepare, save_files, filter_public_events, filter_school_events, filter_community_events
)

import ticket_helpers

# %% [markdown]
# Set output directory

# %%
OUT_DIR = '../../../../docs/metrics/events/making-a-stand/_data/events'

# %% [markdown]
#     The criteria are:
#
# * project type is 'Produce (Signature)'
# * event_type contains 'Public Event -'
#
# It's then filtered by project_name is "02 - Making A Stand"

# %%
data = load_raw_data().pipe(filter_by_project, "02 - Making A Stand")
data = data.loc[data.event_type.notna()]

# %% [markdown]
# Run the processing and save the files

# %%
data.pipe(prepare).pipe(save_files, OUT_DIR)
# Out:
#       actual_audience_size_number_of_participants_in_person  \
# 500                                                 NaN
# 509                                                 NaN
# 594                                                 NaN
# 615                                                 NaN
# 619                                                 NaN
# ...                                                 ...
# 1454                                               30.0
# 1505                                              609.0
# 1506                                                NaN
# 1518                                                NaN
# 1531                                                NaN
#
#       actual_audience_size_number_of_participants_online  airtable_id  \
# 500                                                 NaN           569
# 509                                                 NaN          1194
# 594                                                 NaN          1200
# 615                                                 NaN           587
# 619                                                 NaN           584
# ...                                                 ...           ...
# 1454                                                NaN          2129
# 1505                                                NaN          1564
# 1506                                                NaN          1842
# 1518                                                NaN          1841
# 1531                                                NaN          1843
#
#         end_date                                     event_name  \
# 500   2023-04-13                        Writing for Performance
# 509   2023-04-21    Blind and Visually Impaired Drop-in Session
# 594   2023-04-20    Performance, Politics and Protest Rehearsal
# 615   2023-04-27                   Choral Performance Rehearsal
# 619   2023-04-27              Performance, Politics and Protest
# ...          ...                                            ...
# 1454  2023-11-29  Arts & Social Engagement - Hannah Butterfield
# 1505  2023-12-08                       LBU Christmas Activation
# 1506  2023-12-14              Making A Stand: LEEDS BID Install
# 1518  2023-12-23                      Making A Stand: LEEDS BID
# 1531  2023-12-24               MAking A Stand LEEDS BID - Derig
#
#                                   event_type  \
# 500           ['Public Event - Performance']
# 509           ['Public Event - Talk / Tour']
# 594           ['Public Event - Performance']
# 615   ['CLE - Community Engagement session']
# 619           ['Public Event - Performance']
# ...                                      ...
# 1454          ['Public Event - Performance']
# 1505          ['Public Event - Performance']
# 1506         ['Public Event - Installation']
# 1518         ['Public Event - Installation']
# 1531         ['Public Event - Installation']
#
#                                 event_unique_identifier  \
# 500        02 - Making A Stand: Writing for Performance
# 509   02 - Making A Stand: Blind and Visually Impair...
# 594   02 - Making A Stand: Performance, Politics and...
# 615   02 - Making A Stand: Choral Performance Rehearsal
# 619   02 - Making A Stand: Performance, Politics and...
# ...                                                 ...
# 1454  02 - Making A Stand: Arts & Social Engagement ...
# 1505      02 - Making A Stand: LBU Christmas Activation
# 1506  02 - Making A Stand: Making A Stand: LEEDS BID...
# 1518     02 - Making A Stand: Making A Stand: LEEDS BID
# 1531  02 - Making A Stand: MAking A Stand LEEDS BID ...
#
#       number_of_booked_participants postcode_(from_venue)  \
# 500                             NaN           ['LS1 2HA']
# 509                             NaN                   NaN
# 594                             NaN           ['LS2 7HY']
# 615                             NaN           ['LS1 2HA']
# 619                             NaN           ['LS2 7HY']
# ...                             ...                   ...
# 1454                            NaN                   NaN
# 1505                            NaN           ['LS1 2HA']
# 1506                            NaN                   NaN
# 1518                            NaN                   NaN
# 1531                            NaN                   NaN
#
#              project_name         project_type                    season  \
# 500   02 - Making A Stand  Produce (Signature)    ['Season 2 - Playing']
# 509   02 - Making A Stand  Produce (Signature)  ['Season 1 - Awakening']
# 594   02 - Making A Stand              Promote  ['Season 1 - Awakening']
# 615   02 - Making A Stand  Produce (Signature)    ['Season 2 - Playing']
# 619   02 - Making A Stand              Promote  ['Season 1 - Awakening']
# ...                   ...                  ...                       ...
# 1454  02 - Making A Stand  Produce (Signature)   ['Season 3 - Dreaming']
# 1505  02 - Making A Stand  Produce (Signature)   ['Season 3 - Dreaming']
# 1506  02 - Making A Stand              Partner                       NaN
# 1518  02 - Making A Stand              Partner                       NaN
# 1531  02 - Making A Stand              Partner                       NaN
#
#      start_date ticket_tailor_id                ward_(from_venue)  \
# 500  2023-04-13              NaN  ['Little London and Woodhouse']
# 509  2023-04-17              NaN                              NaN
# 594  2023-04-20              NaN  ['Little London and Woodhouse']
# 615  2023-04-27              NaN  ['Little London and Woodhouse']
# 619  2023-04-27              NaN  ['Little London and Woodhouse']
# ...         ...              ...                              ...
# 1454 2023-11-29              NaN                              NaN
# 1505 2023-12-08              NaN  ['Little London and Woodhouse']
# 1506 2023-12-11              NaN                              NaN
# 1518 2023-12-15              NaN                              NaN
# 1531 2023-12-24              NaN                              NaN
#
#                         ward_name  ward_code  audience_size
# 500   Little London and Woodhouse  E05011403            0.0
# 509                          <NA>        NaN            0.0
# 594   Little London and Woodhouse  E05011403            0.0
# 615   Little London and Woodhouse  E05011403            0.0
# 619   Little London and Woodhouse  E05011403            0.0
# ...                           ...        ...            ...
# 1454                         <NA>        NaN           30.0
# 1505  Little London and Woodhouse  E05011403          609.0
# 1506                         <NA>        NaN            0.0
# 1518                         <NA>        NaN            0.0
# 1531                         <NA>        NaN            0.0
#
# [64 rows x 18 columns]

# %% [markdown]
# Filter by public events

# %%
PUBLIC_EVENTS_DIR = OUT_DIR+'/public'
os.makedirs(PUBLIC_EVENTS_DIR, exist_ok=True)


data.pipe(filter_public_events).pipe(prepare).pipe(save_files, PUBLIC_EVENTS_DIR)
# Out:
#       actual_audience_size_number_of_participants_in_person  \
# 500                                                 NaN
# 509                                                 NaN
# 594                                                 NaN
# 619                                                 NaN
# 625                                                 NaN
# ...                                                 ...
# 1454                                               30.0
# 1505                                              609.0
# 1506                                                NaN
# 1518                                                NaN
# 1531                                                NaN
#
#       actual_audience_size_number_of_participants_online  airtable_id  \
# 500                                                 NaN           569
# 509                                                 NaN          1194
# 594                                                 NaN          1200
# 619                                                 NaN           584
# 625                                                 NaN           585
# ...                                                 ...           ...
# 1454                                                NaN          2129
# 1505                                                NaN          1564
# 1506                                                NaN          1842
# 1518                                                NaN          1841
# 1531                                                NaN          1843
#
#         end_date                                     event_name  \
# 500   2023-04-13                        Writing for Performance
# 509   2023-04-21    Blind and Visually Impaired Drop-in Session
# 594   2023-04-20    Performance, Politics and Protest Rehearsal
# 619   2023-04-27              Performance, Politics and Protest
# 625   2023-04-29               Physical Practitioner Activation
# ...          ...                                            ...
# 1454  2023-11-29  Arts & Social Engagement - Hannah Butterfield
# 1505  2023-12-08                       LBU Christmas Activation
# 1506  2023-12-14              Making A Stand: LEEDS BID Install
# 1518  2023-12-23                      Making A Stand: LEEDS BID
# 1531  2023-12-24               MAking A Stand LEEDS BID - Derig
#
#                            event_type  \
# 500    ['Public Event - Performance']
# 509    ['Public Event - Talk / Tour']
# 594    ['Public Event - Performance']
# 619    ['Public Event - Performance']
# 625    ['Public Event - Performance']
# ...                               ...
# 1454   ['Public Event - Performance']
# 1505   ['Public Event - Performance']
# 1506  ['Public Event - Installation']
# 1518  ['Public Event - Installation']
# 1531  ['Public Event - Installation']
#
#                                 event_unique_identifier  \
# 500        02 - Making A Stand: Writing for Performance
# 509   02 - Making A Stand: Blind and Visually Impair...
# 594   02 - Making A Stand: Performance, Politics and...
# 619   02 - Making A Stand: Performance, Politics and...
# 625   02 - Making A Stand: Physical Practitioner Act...
# ...                                                 ...
# 1454  02 - Making A Stand: Arts & Social Engagement ...
# 1505      02 - Making A Stand: LBU Christmas Activation
# 1506  02 - Making A Stand: Making A Stand: LEEDS BID...
# 1518     02 - Making A Stand: Making A Stand: LEEDS BID
# 1531  02 - Making A Stand: MAking A Stand LEEDS BID ...
#
#       number_of_booked_participants postcode_(from_venue)  \
# 500                             NaN           ['LS1 2HA']
# 509                             NaN                   NaN
# 594                             NaN           ['LS2 7HY']
# 619                             NaN           ['LS2 7HY']
# 625                             NaN           ['LS1 2HA']
# ...                             ...                   ...
# 1454                            NaN                   NaN
# 1505                            NaN           ['LS1 2HA']
# 1506                            NaN                   NaN
# 1518                            NaN                   NaN
# 1531                            NaN                   NaN
#
#              project_name         project_type                    season  \
# 500   02 - Making A Stand  Produce (Signature)    ['Season 2 - Playing']
# 509   02 - Making A Stand  Produce (Signature)  ['Season 1 - Awakening']
# 594   02 - Making A Stand              Promote  ['Season 1 - Awakening']
# 619   02 - Making A Stand              Promote  ['Season 1 - Awakening']
# 625   02 - Making A Stand  Produce (Signature)    ['Season 2 - Playing']
# ...                   ...                  ...                       ...
# 1454  02 - Making A Stand  Produce (Signature)   ['Season 3 - Dreaming']
# 1505  02 - Making A Stand  Produce (Signature)   ['Season 3 - Dreaming']
# 1506  02 - Making A Stand              Partner                       NaN
# 1518  02 - Making A Stand              Partner                       NaN
# 1531  02 - Making A Stand              Partner                       NaN
#
#      start_date ticket_tailor_id                ward_(from_venue)  \
# 500  2023-04-13              NaN  ['Little London and Woodhouse']
# 509  2023-04-17              NaN                              NaN
# 594  2023-04-20              NaN  ['Little London and Woodhouse']
# 619  2023-04-27              NaN  ['Little London and Woodhouse']
# 625  2023-04-29              NaN  ['Little London and Woodhouse']
# ...         ...              ...                              ...
# 1454 2023-11-29              NaN                              NaN
# 1505 2023-12-08              NaN  ['Little London and Woodhouse']
# 1506 2023-12-11              NaN                              NaN
# 1518 2023-12-15              NaN                              NaN
# 1531 2023-12-24              NaN                              NaN
#
#                         ward_name  ward_code  audience_size
# 500   Little London and Woodhouse  E05011403            0.0
# 509                          <NA>        NaN            0.0
# 594   Little London and Woodhouse  E05011403            0.0
# 619   Little London and Woodhouse  E05011403            0.0
# 625   Little London and Woodhouse  E05011403            0.0
# ...                           ...        ...            ...
# 1454                         <NA>        NaN           30.0
# 1505  Little London and Woodhouse  E05011403          609.0
# 1506                         <NA>        NaN            0.0
# 1518                         <NA>        NaN            0.0
# 1531                         <NA>        NaN            0.0
#
# [61 rows x 18 columns]

# %% [markdown]
# Filter by Community events

# %%
# COMMUNITY_EVENTS_DIR = OUT_DIR+'/community'
# os.makedirs(COMMUNITY_EVENTS_DIR, exist_ok=True)

# data.pipe(filter_community_events).pipe(prepare).pipe(save_files, COMMUNITY_EVENTS_DIR)

# %% [markdown]
# Filter by Schools events

# %%
# SCHOOLS_EVENTS_DIR = OUT_DIR+'/schools'
# os.makedirs(SCHOOLS_EVENTS_DIR, exist_ok=True)


# data.pipe(filter_school_events).pipe(prepare).pipe(save_files, SCHOOLS_EVENTS_DIR)
