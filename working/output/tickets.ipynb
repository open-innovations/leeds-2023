# %%
import pandas as pd

# %%
ticket_data = pd.read_csv('../../../../working/metrics/ticketing/orders.csv', parse_dates=['created_at', 'event_date'])

# %%
ticket_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3301 entries, 0 to 3300
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   object                  3301 non-null   object
#  1   id                      3301 non-null   object
#  2   postcode_from_question  3131 non-null   object
#  3   postcode_from_address   34 non-null     object
#  4   created_at              3301 non-null   datetime64[ns]
#  5   event_id                3301 non-null   object
#  6   event_name              3301 non-null   object
#  7   event_date              3301 non-null   datetime64[ns]
#  8   number_of_tickets       3301 non-null   int64
#  9   referral_tag            0 non-null      float64
#  10  status                  3301 non-null   object
#  11  status_message          52 non-null     object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(8)
# memory usage: 309.6+ KB

# %%
completed_orders = ticket_data.loc[~ticket_data.status.isin(['cancelled']), ticket_data.columns]

# %%
chart = completed_orders.groupby(['event_name']).number_of_tickets.sum().plot.bar()

# %%
chart = completed_orders.groupby(['event_date']).number_of_tickets.sum().resample('M').sum().plot.bar()
